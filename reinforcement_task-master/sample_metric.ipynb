# %%
import pandas as pd
from metric import decision_prices

# %% [markdown]
# Загружаем тестовую выборку

# %%
test = pd.read_excel('../reinforcement_task-master/data/test.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Darin_btw\Documents\GitHub\intensiv_3\.venv\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %% [markdown]
# Базовая стратеги - закупка 1 раз в две недели

# %%
test.loc[::2,'Объем'] = 2 
test['Объем'] = test['Объем'].fillna(0)

# %%
test
# Out:
#            dt  Цена на арматуру  Объем
# 0  2022-09-05             46000    2.0
# 1  2022-09-12             46000    0.0
# 2  2022-09-19             46000    2.0
# 3  2022-09-26             45500    0.0
# 4  2022-10-03             45500    2.0
# 5  2022-10-10             45000    0.0
# 6  2022-10-17             44000    2.0
# 7  2022-10-24             43000    0.0
# 8  2022-10-31             42000    2.0
# 9  2022-11-07             41500    0.0
# 10 2022-11-14             41000    2.0
# 11 2022-11-21             40000    0.0
# 12 2022-11-28             40000    2.0
# 13 2022-12-05             40500    0.0
# 14 2022-12-12             41700    2.0
# 15 2022-12-19             41700    0.0
# 16 2022-12-26             42500    2.0
# 17 2023-01-02             42700    0.0
# 18 2023-01-09             42700    2.0
# 19 2023-01-16             42700    0.0
# 20 2023-01-23             42800    2.0
# 21 2023-01-30             42800    0.0
# 22 2023-02-06             44500    2.0
# ...

# %%
test.to_excel('sample_submission.xlsx', index=False)

# %% [markdown]
# Считаем затраты на арматуру

# %%
test_submission = pd.read_excel('sample_submission.xlsx')

# %%
decision_prices(test_submission)
# Out:
# 1236800
